# %%
from pprint import pprint
import time
import requests
import pandas as pd
import datetime
import matplotlib.pyplot as plt
from config import rapidapi_key
import datetime
import math

# %% [markdown]
# # Unorganized Data

# %%
#reading in all covid19 data

time_series_ncov_Confirmed =pd.read_csv('../../../mvp/data/covid19_data/time_series-ncov-Confirmed.csv')
time_series_ncov_Deaths = pd.read_csv('../../../mvp/data/covid19_data/time_series-ncov-Deaths.csv')
time_series_ncov_Recovered =pd.read_csv('../../../mvp/data/covid19_data/time_series-ncov-Recovered.csv')

# %%
#Removing Unecessary Columns in each data frame
time_series_ncov_Confirmed =time_series_ncov_Confirmed.drop(columns =['Province/State'])
time_series_ncov_Deaths =time_series_ncov_Deaths.drop(columns =['Province/State'])
time_series_ncov_Recovered =time_series_ncov_Recovered.drop(columns =['Province/State'])
time_series_ncov_Confirmed.head()
# Out:
#   Country/Region       Lat      Long        Date                         Value
# 0  #country+name  #geo+lat  #geo+lon       #date  #affected+infected+value+num
# 1    Afghanistan      33.0      65.0  2020-03-20                            24
# 2    Afghanistan      33.0      65.0  2020-03-19                            22
# 3    Afghanistan      33.0      65.0  2020-03-18                            22
# 4    Afghanistan      33.0      65.0  2020-03-17                            22

# %%
#Removing unecessary rows in each data set

time_series_ncov_Confirmed =time_series_ncov_Confirmed.drop([0], axis = 0)
time_series_ncov_Deaths =time_series_ncov_Deaths.drop([0], axis = 0)
time_series_ncov_Recovered =time_series_ncov_Recovered.drop([0], axis = 0)
time_series_ncov_Deaths.head()



# Changing all value columns to numeric for analysis
time_series_ncov_Confirmed["Value"] = pd.to_numeric(time_series_ncov_Confirmed["Value"])
time_series_ncov_Deaths["Value"] = pd.to_numeric(time_series_ncov_Deaths["Value"])
time_series_ncov_Recovered["Value"] = pd.to_numeric(time_series_ncov_Recovered["Value"])


time_series_ncov_Confirmed["Date"] = pd.to_datetime(time_series_ncov_Confirmed["Date"])
time_series_ncov_Deaths["Date"] = pd.to_datetime(time_series_ncov_Deaths["Date"])
time_series_ncov_Recovered["Date"] = pd.to_datetime(time_series_ncov_Recovered["Date"])

time_series_ncov_Confirmed.dtypes

#Renaming value columns to be easier to analyze

time_series_ncov_Confirmed= time_series_ncov_Confirmed.rename(columns ={'Value':'Confirmed Cases'})
time_series_ncov_Deaths= time_series_ncov_Deaths.rename(columns ={'Value':'Deaths'})
time_series_ncov_Recovered= time_series_ncov_Recovered.rename(columns ={'Value':'Recoveries'})
time_series_ncov_Confirmed.head()
# Out:
#   Country/Region   Lat  Long       Date  Confirmed Cases
# 1    Afghanistan  33.0  65.0 2020-03-20             24.0
# 2    Afghanistan  33.0  65.0 2020-03-19             22.0
# 3    Afghanistan  33.0  65.0 2020-03-18             22.0
# 4    Afghanistan  33.0  65.0 2020-03-17             22.0
# 5    Afghanistan  33.0  65.0 2020-03-16             21.0

# %%
confirm_count = 0
first_country = "Afghanistan"
new_confirmed_cases =[]

confirmed_cases_list = time_series_ncov_Confirmed['Confirmed Cases'].to_list()
countries_list = time_series_ncov_Confirmed['Country/Region'].to_list()
        
for i in confirmed_cases_list:
    for country in countries_list:
        if country == first_country
            new_confirm = i-confirm_count
            new_confirmed_cases.append(new_confirm)
            confirm_count = i
        else:
        first_country = country
        confirm_count = 0

# %%
#Create a list for all of the dates in the COVID-19 CSV File
Dates = time_series_ncov_Confirmed['Date'].unique()

# %%
#time_series_ncov_Deaths= time_series_ncov_Deaths.drop(columns =['Lat','Long'])
#time_series_ncov_Recovered= time_series_ncov_Recovered.drop(columns =['Lat','Long'])

# %%
#Grouping all dataframes by country/region and the date to get total values for each data set

time_series_nconv_Confirmed = time_series_ncov_Confirmed.groupby(['Country/Region','Date']).sum()['Confirmed Cases']
time_series_nconv_Deaths = time_series_ncov_Deaths.groupby(['Country/Region','Date']).sum()['Deaths']
time_series_nconv_Recovered = time_series_ncov_Recovered.groupby(['Country/Region','Date']).sum()['Recoveries']

confirmed_all = pd.DataFrame({
    "Confirmed Cases": time_series_nconv_Confirmed,
    "Deaths": time_series_nconv_Deaths,
    "Recoveries": time_series_nconv_Recovered
})
confirmed_all.head()
# Out:
#                            Confirmed Cases  Deaths  Recoveries
# Country/Region Date
# Afghanistan    2020-01-22              0.0     0.0         0.0
#                2020-01-23              0.0     0.0         0.0
#                2020-01-24              0.0     0.0         0.0
#                2020-01-25              0.0     0.0         0.0
#                2020-01-26              0.0     0.0         0.0

# %%
confirmed_all.loc["Italy"]['Confirmed Cases'].head()
# Out:
# Date
# 2020-01-22    0.0
# 2020-01-23    0.0
# 2020-01-24    0.0
# 2020-01-25    0.0
# 2020-01-26    0.0
# Name: Confirmed Cases, dtype: float64

# %%
#Create column for daily changes
confirm_count = 0
death_count = 0
recovery_count = 0

new_confirmed_cases =[]
new_deaths =[]
new_recoveries = []

confirmed_cases_list = confirmed_all['Confirmed Cases'].to_list()
deaths_list = confirmed_all['Deaths'].to_list()
recoveries_list = confirmed_all['Recoveries'].to_list()

unique_countries = time_series_ncov_Confirmed['Country/Region'].unique()

for i in confirmed_cases_list:
    new_confirm = i-confirm_count
    new_confirmed_cases.append(new_confirm)
    confirm_count = i

for k in deaths_list:
    new_dead = k-death_count
    new_deaths.append(new_dead)
    death_count = k

for j in recoveries_list:
    new_recover = j-recovery_count
    new_recoveries.append(new_recover)
    recovery_count = j

confirmed_all["New Confirmed Cases"]= new_confirmed_cases
confirmed_all["New Deaths"]= new_deaths
confirmed_all["New Recoveries"]= new_recoveries

# %%
# Want to created new columns showing the ratio between how many confirmed cases have been

# confirmed_all["Recover/Confirm Ratio"] = confirmed_all["Recoveries"]/confirmed_all["Confirmed Cases"]
confirmed_all.loc["Albania"].head()
#confirmed_all.sort_values(by = 'Recoveries')
# Out:
#             Confirmed Cases  Deaths  Recoveries
# Date
# 2020-01-22              0.0     0.0         0.0
# 2020-01-23              0.0     0.0         0.0
# 2020-01-24              0.0     0.0         0.0
# 2020-01-25              0.0     0.0         0.0
# 2020-01-26              0.0     0.0         0.0

# %%
confirmed_all.loc[["Italy"]]["Confirmed Cases"].head()
# Out:
# Country/Region  Date
# Italy           2020-01-22    0.0
#                 2020-01-23    0.0
#                 2020-01-24    0.0
#                 2020-01-25    0.0
#                 2020-01-26    0.0
# Name: Confirmed Cases, dtype: float64

# %%
#confirmed_all.reset_index(inplace=True)
#fd = confirmed_all.loc[confirmed_all['Country/Region'] == 'Italy']['Confirmed Cases']

# %%
confirmed_group=pd.DataFrame({
    #'x': confirmed_all.loc["Italy"]['Confirmed Cases'].index,
    'Italy': confirmed_all.loc["Italy"]["Confirmed Cases"], 
    'US': confirmed_all.loc["US"]["Confirmed Cases"],
    'China': confirmed_all.loc["China"]["Confirmed Cases"]
})

confirmed_group.plot()
#ax.xaxis.set_major_locator(months)
#ax.xaxis.set_major_formatter(years_fmt)
plt.show()
#plt.plot('x','y1', data = df, markerfacecolor='blue', markersize=12, color='skyblue', linewidth=4)

# %%
death_group=pd.DataFrame({
    #'x': confirmed_all.loc["Italy"]['Confirmed Cases'].index,
    'Italy': confirmed_all.loc["Italy"]["Deaths"], 
    'US': confirmed_all.loc["US"]["Deaths"],
    'China': confirmed_all.loc["China"]["Deaths"]
})

death_group.plot()
plt.show()

# %%
death_group=pd.DataFrame({
    #'x': confirmed_all.loc["Italy"]['Confirmed Cases'].index,
    'Italy': confirmed_all.loc["Italy"]["Deaths"], 
    'US': confirmed_all.loc["US"]["Deaths"],
    'China': confirmed_all.loc["China"]["Deaths"]
})

death_group.plot()
plt.show()

# %%
recoveries_group=pd.DataFrame({
    #'x': confirmed_all.loc["Italy"]['Confirmed Cases'].index,
    'Italy': confirmed_all.loc["Italy"]["Recoveries"], 
    'US': confirmed_all.loc["US"]["Recoveries"],
    'China': confirmed_all.loc["China"]["Recoveries"]
})

recoveries_group.plot()
plt.show()

# %%
#Line charts for confirm, death, recovered in each country

# %%
#Determine the dates each country experienced the largest number of confirms, deaths and recoveries
#Also determine the dates each respective stock market, had the largest increases and drops

# %%
#

# %%
#chart comparing the respective stock market along

# %% [markdown]
# # Italian Market

# %%
italy_df = pd.read_csv("../italy_index/FTSE Italia All Share Historical Data.csv")

# %%
italy_df
# Out:
#           Date     Price      Open      High       Low        Vol.  Change %  \
# 0    2020-3-20  17171.55  17209.93  17628.87  17047.73  1500000000      1.85
# 1    2020-3-19  16859.82  16814.38  17240.13  16438.49  1270000000      2.27
# 2    2020-3-18  16486.21  16372.27  16785.57  16149.48   992760000     -1.17
# 3    2020-3-17  16680.56  16850.34  17238.59  16065.72  1400000000      1.96
# 4    2020-3-16  16360.04  17130.96  17130.96  15498.19  1540000000     -6.06
# ..         ...       ...       ...       ...       ...         ...       ...
# 321  2018-12-7  20597.68  20650.69  20818.51  20597.68   616630000      0.49
# 322  2018-12-6  20496.44  21014.83  21014.83  20433.79  1090000000     -3.38
# 323  2018-12-5  21213.03  21041.15  21287.70  20990.68   691120000     -0.19
# 324  2018-12-4  21254.03  21494.44  21517.80  21254.03   961020000     -1.26
# 325  2018-12-3  21525.70  21476.90  21567.83  21421.42  1520000000      2.22
#
#       Timestamp
# 0    1584662400
# 1    1584576000
# 2    1584489600
# 3    1584403200
# 4    1584316800
# ..          ...
# 321  1544140800
# 322  1544054400
# 323  1543968000
# 324  1543881600
# 325  1543795200
#
# [326 rows x 8 columns]

# %% [markdown]
# # Chinese Market

# %%
curr_time = int(time.time())
#prior_year = curr_time-(60*60*24*365)
prior_year = 1543622400  # unix for December 01,2018
ticker_symbol = "000001.SS"

# %%
url = "https://apidojo-yahoo-finance-v1.p.rapidapi.com/market/get-summary"

querystring = {"region":"US","lang":"en","symbol":ticker_symbol,"from":prior_year,"to":curr_time,"events":"div","events":"split","events":"earn","interval":"1d"}

headers = {
    'x-rapidapi-host': "apidojo-yahoo-finance-v1.p.rapidapi.com",
    'x-rapidapi-key': "b477e42517mshf0183273bba2e47p1544cbjsnc7d400ac9422"
    }
response = requests.request("GET", url, headers=headers, params=querystring)

# %%
response.json()
# Out:
# {'marketSummaryResponse': {'result': [{'fullExchangeName': 'SNP',
#     'exchangeTimezoneName': 'America/New_York',
#     'symbol': '^GSPC',
#     'regularMarketChange': {'raw': 209.93018, 'fmt': '209.93'},
#     'gmtOffSetMilliseconds': -14400000,
#     'exchangeDataDelayedBy': 0,
#     'language': 'en',
#     'regularMarketTime': {'raw': 1585084415, 'fmt': '5:13PM EDT'},
#     'exchangeTimezoneShortName': 'EDT',
#     'regularMarketChangePercent': {'raw': 9.382774, 'fmt': '9.38%'},
#     'quoteType': 'INDEX',
#     'marketState': 'POST',
#     'regularMarketPrice': {'raw': 2447.33, 'fmt': '2,447.33'},
#     'market': 'us_market',
#     'priceHint': 2,
#     'tradeable': False,
#     'exchange': 'SNP',
#     'sourceInterval': 15,
#     'region': 'US',
#     'shortName': 'S&P 500',
#     'triggerable': True,
#     'regularMarketPreviousClose': {'raw': 2237.4, 'fmt': '2,237.40'}},
#    {'fullExchangeName': 'DJI',
#     'exchangeTimezoneName': 'America/New_York',
#     'symbol': '^DJI',
#     'regularMarketChange': {'raw': 2112.9805, 'fmt': '2,112.98'},
#     'gmtOffSetMilliseconds': -14400000,
#     'exchangeDataDelayedBy': 0,
#     'language': 'en',
#     'regularMarketTime': {'raw': 1585084415, 'fmt': '5:13PM EDT'},
#     'exchangeTimezoneShortName': 'EDT',
#     'regularMarketChangePercent': {'raw': 11.365041, 'fmt': '11.37%'},
#     'quoteType': 'INDEX',
#     'marketState': 'POST',
#     'regularMarketPrice': {'raw': 20704.91, 'fmt': '20,704.91'},
#     'market': 'us_market',
#     'priceHint': 2,
#     'tradeable': False,
#     'exchange': 'DJI',
#     'sourceInterval': 120,
#     'region': 'US',
#     'shortName': 'Dow 30',
#     'triggerable': True,
#     'regularMarketPreviousClose': {'raw': 18591.93, 'fmt': '18,591.93'}},
#    {'fullExchangeName': 'Nasdaq GIDS',
#     'exchangeTimezoneName': 'America/New_York',
#     'symbol': '^IXIC',
#     'regularMarketChange': {'raw': 557.1836, 'fmt': '557.18'},
#     'gmtOffSetMilliseconds': -14400000,
#     'exchangeDataDelayedBy': 0,
#     'language': 'en',
#     'regularMarketTime': {'raw': 1585084559, 'fmt': '5:15PM EDT'},
#     'exchangeTimezoneShortName': 'EDT',
#     'regularMarketChangePercent': {'raw': 8.121412, 'fmt': '8.12%'},
#     'quoteType': 'INDEX',
#     'marketState': 'POST',
#     'regularMarketPrice': {'raw': 7417.857, 'fmt': '7,417.86'},
#     'market': 'us_market',
#     'priceHint': 2,
#     'tradeable': False,
#     'exchange': 'NIM',
#     'sourceInterval': 15,
#     'region': 'US',
#     'shortName': 'Nasdaq',
#     'triggerable': False,
#     'regularMarketPreviousClose': {'raw': 6860.6733, 'fmt': '6,860.67'}},
#    {'fullExchangeName': 'Chicago Options',
#     'exchangeTimezoneName': 'America/New_York',
#     'symbol': '^RUT',
#     'regularMarketChange': {'raw': 94.11774, 'fmt': '94.12'},
#     'gmtOffSetMilliseconds': -14400000,
#     'exchangeDataDelayedBy': 20,
#     'language': 'en',
#     'regularMarketTime': {'raw': 1585081805, 'fmt': '4:30PM EDT'},
#     'exchangeTimezoneShortName': 'EDT',
#     'regularMarketChangePercent': {'raw': 9.389076, 'fmt': '9.39%'},
#     'quoteType': 'INDEX',
#     'marketState': 'POST',
#     'regularMarketPrice': {'raw': 1096.5352, 'fmt': '1,096.54'},
#     'market': 'us_market',
#     'priceHint': 2,
#     'tradeable': False,
#     'exchange': 'WCB',
#     'sourceInterval': 15,
#     'region': 'US',
#     'shortName': 'Russell 2000',
#     'triggerable': False,
#     'regularMarketPreviousClose': {'raw': 1002.4174, 'fmt': '1,002.42'}},
#    {'fullExchangeName': 'NY Mercantile',
#     'exchangeTimezoneName': 'America/New_York',
#     'symbol': 'CL=F',
#     'regularMarketChange': {'raw': 0.289999, 'fmt': '0.29'},
#     'headSymbolAsString': 'CL=F',
#     'gmtOffSetMilliseconds': -14400000,
#     'exchangeDataDelayedBy': 30,
#     'language': 'en',
#     'regularMarketTime': {'raw': 1585087383, 'fmt': '6:03PM EDT'},
#     'exchangeTimezoneShortName': 'EDT',
#     'regularMarketChangePercent': {'raw': 1.2078259, 'fmt': '1.21%'},
#     'quoteType': 'FUTURE',
#     'marketState': 'REGULAR',
#     'regularMarketPrice': {'raw': 24.3, 'fmt': '24.30'},
#     'market': 'us24_market',
#     'tradeable': False,
#     'exchange': 'NYM',
#     'sourceInterval': 30,
#     'region': 'US',
#     'shortName': 'Crude Oil',
#     'triggerable': False,
#     'regularMarketPreviousClose': {'raw': 24.01, 'fmt': '24.01'}},
#    {'fullExchangeName': 'COMEX',
#     'exchangeTimezoneName': 'America/New_York',
#     'symbol': 'GC=F',
#     'regularMarketChange': {'raw': 19.5, 'fmt': '19.50'},
#     'headSymbolAsString': 'GC=F',
#     'gmtOffSetMilliseconds': -14400000,
#     'exchangeDataDelayedBy': 30,
#     'language': 'en',
#     'regularMarketTime': {'raw': 1585087386, 'fmt': '6:03PM EDT'},
#     'exchangeTimezoneShortName': 'EDT',
#     'regularMarketChangePercent': {'raw': 1.174133, 'fmt': '1.17%'},
#     'quoteType': 'FUTURE',
#     'marketState': 'REGULAR',
#     'regularMarketPrice': {'raw': 1680.3, 'fmt': '1,680.30'},
#     'market': 'us24_market',
#     'tradeable': False,
#     'exchange': 'CMX',
#     'sourceInterval': 15,
#     'region': 'US',
#     'shortName': 'Gold',
#     'triggerable': False,
#     'regularMarketPreviousClose': {'raw': 1660.8, 'fmt': '1,660.80'}},
#    {'fullExchangeName': 'COMEX',
#     'exchangeTimezoneName': 'America/New_York',
#     'symbol': 'SI=F',
#     'regularMarketChange': {'raw': 0.27799988, 'fmt': '0.28'},
#     'headSymbolAsString': 'SI=F',
#     'gmtOffSetMilliseconds': -14400000,
#     'exchangeDataDelayedBy': 30,
#     'language': 'en',
#     'regularMarketTime': {'raw': 1585087385, 'fmt': '6:03PM EDT'},
#     'exchangeTimezoneShortName': 'EDT',
#     'regularMarketChangePercent': {'raw': 1.9499185, 'fmt': '1.95%'},
#     'quoteType': 'FUTURE',
#     'marketState': 'REGULAR',
#     'regularMarketPrice': {'raw': 14.535, 'fmt': '14.53'},
#     'market': 'us24_market',
#     'tradeable': False,
#     'exchange': 'CMX',
#     'sourceInterval': 15,
#     'region': 'US',
#     'shortName': 'Silver',
#     'triggerable': False,
#     'regularMarketPreviousClose': {'raw': 14.257, 'fmt': '14.26'}},
#    {'fullExchangeName': 'CCY',
#     'exchangeTimezoneName': 'Europe/London',
#     'symbol': 'EURUSD=X',
#     'regularMarketChange': {'raw': 0.0063763857, 'fmt': '0.0064'},
#     'gmtOffSetMilliseconds': 0,
#     'exchangeDataDelayedBy': 0,
#     'language': 'en-US',
#     'regularMarketTime': {'raw': 1585087975, 'fmt': '10:12PM GMT'},
#     'exchangeTimezoneShortName': 'GMT',
#     'regularMarketChangePercent': {'raw': 0.5939545, 'fmt': '0.5940%'},
#     'quoteType': 'CURRENCY',
#     'marketState': 'REGULAR',
#     'regularMarketPrice': {'raw': 1.0799136, 'fmt': '1.0799'},
#     'market': 'ccy_market',
#     'priceHint': 4,
#     'tradeable': False,
#     'currency': 'USD',
#     'exchange': 'CCY',
#     'sourceInterval': 15,
#     'region': 'US',
#     'shortName': 'EUR/USD',
#     'triggerable': True,
#     'regularMarketPreviousClose': {'raw': 1.0735372, 'fmt': '1.0735'}},
#    {'fullExchangeName': 'NYBOT',
#     'exchangeTimezoneName': 'America/New_York',
#     'symbol': '^TNX',
#     'regularMarketChange': {'raw': 0.051999986, 'fmt': '0.0520'},
#     'gmtOffSetMilliseconds': -14400000,
#     'exchangeDataDelayedBy': 30,
#     'language': 'en',
#     'regularMarketTime': {'raw': 1585076397, 'fmt': '2:59PM EDT'},
#     'exchangeTimezoneShortName': 'EDT',
#     'regularMarketChangePercent': {'raw': 6.806281, 'fmt': '6.81%'},
#     'quoteType': 'INDEX',
#     'marketState': 'REGULAR',
#     'regularMarketPrice': {'raw': 0.816, 'fmt': '0.8160'},
#     'market': 'us24_market',
#     'priceHint': 4,
#     'tradeable': False,
#     'exchange': 'NYB',
#     'sourceInterval': 30,
#     'region': 'US',
#     'shortName': '10-Yr Bond',
#     'triggerable': False,
#     'regularMarketPreviousClose': {'raw': 0.764, 'fmt': '0.7640'},
#     'longName': 'Treasury Yield 10 Years'},
#    {'fullExchangeName': 'Chicago Options',
#     'exchangeTimezoneName': 'America/New_York',
#     'symbol': '^VIX',
#     'regularMarketChange': {'raw': 0.07999802, 'fmt': '0.08'},
#     'gmtOffSetMilliseconds': -14400000,
#     'exchangeDataDelayedBy': 20,
#     'language': 'en',
#     'regularMarketTime': {'raw': 1585080890, 'fmt': '4:14PM EDT'},
#     'exchangeTimezoneShortName': 'EDT',
#     'regularMarketChangePercent': {'raw': 0.129888, 'fmt': '0.13%'},
#     'quoteType': 'INDEX',
#     'marketState': 'POST',
#     'regularMarketPrice': {'raw': 61.67, 'fmt': '61.67'},
#     'market': 'us_market',
#     'priceHint': 2,
#     'tradeable': False,
#     'exchange': 'WCB',
#     'sourceInterval': 15,
#     'region': 'US',
#     'shortName': 'Vix',
#     'triggerable': False,
#     'regularMarketPreviousClose': {'raw': 61.59, 'fmt': '61.59'}},
#    {'fullExchangeName': 'CCY',
#     'exchangeTimezoneName': 'Europe/London',
#     'symbol': 'GBPUSD=X',
#     'regularMarketChange': {'raw': 0.0229069, 'fmt': '0.0229'},
#     'gmtOffSetMilliseconds': 0,
#     'exchangeDataDelayedBy': 0,
#     'language': 'en-US',
#     'regularMarketTime': {'raw': 1585087975, 'fmt': '10:12PM GMT'},
#     'exchangeTimezoneShortName': 'GMT',
#     'regularMarketChangePercent': {'raw': 1.984628, 'fmt': '1.9846%'},
#     'quoteType': 'CURRENCY',
#     'marketState': 'REGULAR',
#     'regularMarketPrice': {'raw': 1.1771215, 'fmt': '1.1771'},
#     'market': 'ccy_market',
#     'priceHint': 4,
#     'tradeable': False,
#     'currency': 'USD',
#     'exchange': 'CCY',
#     'sourceInterval': 15,
#     'region': 'US',
#     'shortName': 'GBP/USD',
#     'triggerable': True,
#     'regularMarketPreviousClose': {'raw': 1.1542146, 'fmt': '1.1542'}},
#    {'fullExchangeName': 'CCY',
#     'exchangeTimezoneName': 'Europe/London',
#     'symbol': 'JPY=X',
#     'regularMarketChange': {'raw': 0.14299774, 'fmt': '0.1430'},
#     'gmtOffSetMilliseconds': 0,
#     'exchangeDataDelayedBy': 0,
#     'language': 'en-US',
#     'regularMarketTime': {'raw': 1585087987, 'fmt': '10:13PM GMT'},
#     'exchangeTimezoneShortName': 'GMT',
#     'regularMarketChangePercent': {'raw': 0.128587, 'fmt': '0.1286%'},
#     'quoteType': 'CURRENCY',
#     'marketState': 'REGULAR',
#     'regularMarketPrice': {'raw': 111.35, 'fmt': '111.3500'},
#     'market': 'ccy_market',
#     'quoteSourceName': 'Delayed Quote',
#     'priceHint': 4,
#     'tradeable': False,
#     'currency': 'JPY',
#     'exchange': 'CCY',
#     'sourceInterval': 15,
#     'region': 'US',
#     'shortName': 'USD/JPY',
#     'triggerable': True,
#     'regularMarketPreviousClose': {'raw': 111.207, 'fmt': '111.2070'}},
#    {'fullExchangeName': 'CCC',
#     'exchangeTimezoneName': 'Europe/London',
#     'symbol': 'BTC-USD',
#     'regularMarketChange': {'raw': 244.63281, 'fmt': '244.63'},
#     'gmtOffSetMilliseconds': 0,
#     'exchangeDataDelayedBy': 0,
#     'language': 'en',
#     'regularMarketTime': {'raw': 1585087897, 'fmt': '10:11PM GMT'},
#     'exchangeTimezoneShortName': 'GMT',
#     'regularMarketChangePercent': {'raw': 3.7850664, 'fmt': '3.79%'},
#     'quoteType': 'CRYPTOCURRENCY',
#     'marketState': 'REGULAR',
#     'regularMarketPrice': {'raw': 6707.738, 'fmt': '6,707.74'},
#     'market': 'ccc_market',
#     'quoteSourceName': 'CryptoCurrency',
#     'tradeable': True,
#     'exchange': 'CCC',
#     'sourceInterval': 15,
#     'region': 'US',
#     'triggerable': True,
#     'regularMarketPreviousClose': {'raw': 6463.105, 'fmt': '6,463.10'}},
#    {'fullExchangeName': 'Nasdaq GIDS',
#     'exchangeTimezoneName': 'America/New_York',
#     'symbol': '^CMC200',
#     'regularMarketChange': {'raw': 4.185898, 'fmt': '4.19'},
#     'gmtOffSetMilliseconds': -14400000,
#     'exchangeDataDelayedBy': 0,
#     'language': 'en',
#     'regularMarketTime': {'raw': 1585087967, 'fmt': '6:12PM EDT'},
#     'exchangeTimezoneShortName': 'EDT',
#     'regularMarketChangePercent': {'raw': 3.174646, 'fmt': '3.17%'},
#     'quoteType': 'INDEX',
#     'marketState': 'POST',
#     'regularMarketPrice': {'raw': 136.0399, 'fmt': '136.04'},
#     'market': 'us_market',
#     'priceHint': 2,
#     'tradeable': False,
#     'exchange': 'NIM',
#     'sourceInterval': 15,
#     'region': 'US',
#     'shortName': 'CMC Crypto 200',
#     'triggerable': False,
#     'regularMarketPreviousClose': {'raw': 131.854, 'fmt': '131.85'}},
#    {'fullExchangeName': 'FTSE Index',
#     'exchangeTimezoneName': 'Europe/London',
#     'symbol': '^FTSE',
#     'regularMarketChange': {'raw': 452.11963, 'fmt': '452.12'},
#     'gmtOffSetMilliseconds': 0,
#     'exchangeDataDelayedBy': 15,
#     'language': 'en',
#     'regularMarketTime': {'raw': 1585068359, 'fmt': '4:45PM GMT'},
#     'exchangeTimezoneShortName': 'GMT',
#     'regularMarketChangePercent': {'raw': 9.053455, 'fmt': '9.05%'},
#     'quoteType': 'INDEX',
#     'marketState': 'POSTPOST',
#     'regularMarketPrice': {'raw': 5446.01, 'fmt': '5,446.01'},
#     'market': 'gb_market',
#     'priceHint': 2,
#     'tradeable': False,
#     'exchange': 'FGI',
#     'sourceInterval': 15,
#     'region': 'US',
#     'shortName': 'FTSE 100',
#     'triggerable': False,
#     'regularMarketPreviousClose': {'raw': 4993.89, 'fmt': '4,993.89'}},
#    {'fullExchangeName': 'Osaka',
#     'exchangeTimezoneName': 'Asia/Tokyo',
#     'symbol': '^N225',
#     'regularMarketChange': {'raw': 1204.5703, 'fmt': '1,204.57'},
#     'gmtOffSetMilliseconds': 32400000,
#     'exchangeDataDelayedBy': 0,
#     'language': 'en',
#     'regularMarketTime': {'raw': 1585030502, 'fmt': '3:15PM JST'},
#     'exchangeTimezoneShortName': 'JST',
#     'regularMarketChangePercent': {'raw': 7.132793, 'fmt': '7.13%'},
#     'quoteType': 'INDEX',
#     'marketState': 'PREPRE',
#     'regularMarketPrice': {'raw': 18092.35, 'fmt': '18,092.35'},
#     'market': 'jp_market',
#     'priceHint': 2,
#     'tradeable': False,
#     'exchange': 'OSA',
#     'sourceInterval': 20,
#     'region': 'US',
#     'shortName': 'Nikkei 225',
#     'triggerable': False,
#     'regularMarketPreviousClose': {'raw': 16887.78, 'fmt': '16,887.78'}}],
#   'error': None}}

# %%
timestamp = response.json()['marketSummaryResponse']['result'][0]['timestamp']
year_close = response.json()['chart']['result'][0]['indicators']['quote'][0]['close']
year_open =response.json()['chart']['result'][0]['indicators']['quote'][0]['open']
year_volume =response.json()['chart']['result'][0]['indicators']['quote'][0]['volume']
year_adjclose =response.json()['chart']['result'][0]['indicators']['adjclose'][0]['adjclose']

ssec_Dict = {"Timestamp":timestamp,
           "Open":year_open,
          "Close":year_close,
           "Volume":year_volume,
          "Adjclose":year_adjclose
          }
ssec_df = pd.DataFrame(ssec_Dict)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-79-b05ab744d4d1> in <module>
# ----> 1 timestamp = response.json()['marketSummaryResponse']['result'][0]['timestamp']
#       2 year_close = response.json()['chart']['result'][0]['indicators']['quote'][0]['close']
#       3 year_open =response.json()['chart']['result'][0]['indicators']['quote'][0]['open']
#       4 year_volume =response.json()['chart']['result'][0]['indicators']['quote'][0]['volume']
#       5 year_adjclose =response.json()['chart']['result'][0]['indicators']['adjclose'][0]['adjclose']
#
# KeyError: 'timestamp'
